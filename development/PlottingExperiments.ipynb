# %% [markdown]
# # Initialisation

# %%
from nitpick.fileIO import Patcher, History

# %%
#import matplotlib.pyplot as plt
#import matplotlib
import numpy as np
import pandas as pd
#%matplotlib inline

# %% [markdown]
# ## Example Model Run

# %%
from random import randrange
from nupic.research.spatial_pooler import SpatialPooler
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# <ipython-input-1-7290c319651d> in <module>()
#       1 from random import randrange
# ----> 2 from nupic.research.spatial_pooler import SpatialPooler
#
# ImportError: No module named nupic.research.spatial_pooler

# %%
def generateInput(inputArray):
  inputArray[0:] = 0
  for i in range(inputArray.size):
    inputArray[i] = randrange(2)

# %%
sp = SpatialPooler(inputDimensions=[20, 20],
                   columnDimensions=[15, 15],
                   potentialRadius=4,
                   potentialPct=0.5,
                   synPermInactiveDec=0.1,
                   synPermActiveInc=0.1,
                   synPermConnected=0.1,
                   localAreaDensity=0.1,
                   numActiveColumnsPerInhArea=-1,
                   globalInhibition=False)

# %%
inputArray = np.zeros(sp.getNumInputs())
activeArray = np.zeros(sp.getNumColumns())

# %%
Patcher().patchSP(sp)

# %%
for i in range(50):
    generateInput(inputArray)
    sp.compute(inputArray, True, activeArray)
print "done"
# Out:
# done

# %% [markdown]
# # Bokeh Plots

# %%
import bokeh
bokeh.load_notebook()
# Out:
#
#         <style>
#             /* BEGIN /home/ruaridh/pythonEnviroments/pandasEnv/local/lib/python2.7/site-packages/bokeh/server/static/css/bokeh.min.css */
#                 /*! jQuery UI - v1.10.0 - 2013-01-17
#                 * http://jqueryui.com
#                 * Includes: jquery.ui.core.css, jquery.ui.accordion.css, jquery.ui.autocomplete.css, jquery.ui.button.css, jquery.ui.datepicker.css, jquery.ui.dialog.css, jquery.ui.menu.css, jquery.ui.progressbar.css, jquery.ui.resizable.css, jquery.ui.selectable.css, jquery.ui.slider.css, jquery.ui.spinner.css, jquery.ui.tabs.css, jquery.ui.tooltip.css, jquery.ui.theme.css
# ...

# %%
points = pd.DataFrame([[0,2,4,5,1,6,8,7,9,5,4,2,3,6,8,5,4,1,2,3,5,4,8,5,4,5,5,5,5,4],[5,5,5,4,8,7,5,9,6,3,2,1,0,0,1,2,3,6,5,8,9,7,5,6,4,5,3,3,4,8]]).T

# %%
points.columns = ['xPos','yPos']

# %%
points
# Out:
#     xPos  yPos
# 0      0     5
# 1      2     5
# 2      4     5
# 3      5     4
# 4      1     8
# 5      6     7
# 6      8     5
# 7      7     9
# 8      9     6
# 9      5     3
# 10     4     2
# 11     2     1
# 12     3     0
# 13     6     0
# 14     8     1
# 15     5     2
# 16     4     3
# 17     1     6
# 18     2     5
# 19     3     8
# 20     5     9
# 21     4     7
# 22     8     5
# 23     5     6
# 24     4     4
# 25     5     5
# 26     5     3
# 27     5     3
# 28     5     4
# 29     4     8

# %%
r=np.random.randn(100)

# %%
import bokeh.charts as c

# %%
c.Scatter(points,notebook=True)

# %%
_48.show()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-49-4e3a0442dd7f> in <module>()
# ----> 1 _48.show()
#
# /home/ruaridh/pythonEnviroments/pandasEnv/local/lib/python2.7/site-packages/bokeh/charts/scatter.pyc in show(self)
#     201         # asumming we get an hierchiral pandas object
#     202         if isinstance(self.pairs, pd.DataFrame):
# --> 203             self.labels = self.pairs.columns.levels[1].values
#     204
#     205             from collections import OrderedDict
#
# AttributeError: 'Index' object has no attribute 'levels'

# %%
pd.DataFrame

# %%
r=pd.DataFrame(r)

# %%
h=Histogram(r,mu=0,sigma=0.5,bins=10,notebook=True)

# %%
h.show()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-40-047a582766f4> in <module>()
# ----> 1 h.show()
#
# /home/ruaridh/pythonEnviroments/pandasEnv/local/lib/python2.7/site-packages/bokeh/charts/histogram.pyc in show(self)
#     244         self.start_plot()
#     245         # we get the data from the incoming input
# --> 246         self.get_data(self.bins, self.mu, self.sigma, **self.measured)
#     247         # we filled the source and ranges with the calculated data
#     248         self.get_source()
#
# TypeError: get_data() keywords must be strings

# %% [markdown]
# # Permenence Line Plots

# %%
s = sp.history.proximalSynapses()

# %%
l=[[synapse for synapse in item if synapse[0] == 1] for item in s]

# %%
l=np.array(l)

# %%
l[:,:,2]
# Out:
# array([[ 0.06899,  0.09279,  0.06822, ...,  0.11862,  0.12001,  0.11132],
#        [ 0.06899,  0.09279,  0.06822, ...,  0.11862,  0.12001,  0.11132],
#        [ 0.06899,  0.09279,  0.06822, ...,  0.11862,  0.12001,  0.11132],
#        ...,
#        [ 0.06899,  0.09279,  0.06822, ...,  0.11862,  0.12001,  0.11132],
#        [ 0.06899,  0.09279,  0.06822, ...,  0.11862,  0.12001,  0.11132],
#        [ 0.06899,  0.09279,  0.06822, ...,  0.11862,  0.12001,  0.11132]])

# %%
plt.plot(_)

# %% [markdown]
# # Array Plots Of Various Types

# %%
#import numpy
#import matplotlib.pyplot as plt
import matplotlib.ticker

def arrayPlot(array):
    (figure,axes) = plt.subplots()
    
    cAxes = axes.matshow(array,cmap='binary')
    
    figure.colorbar(cAxes)
    
    loc = matplotlib.ticker.IndexLocator(1,0)
    
    axes.xaxis.set_minor_locator(loc)
    axes.yaxis.set_minor_locator(loc)
       
    axes.grid(True,axis='both',which='minor',linestyle='solid',color=(0.7,0.7,0.7))
    
    #figure.set_size_inches(50,50)

# %%
reload(plots)
# Out:
# <module 'nitpick.plots' from '/home/ruaridh/nitpick/nitpick/plots/__init__.py'>

# %%
def sparseArrayPlot(indexes,dimensions):
    denseArray = np.zeros(dimensions[0]*dimensions[1])
    denseArray[indexes]=1
    denseArray = np.reshape(denseArray,dimensions)
    
    arrayPlot(denseArray)

# %%
a=plots.sparseArrayPlot(sp.history.activeColumns()[50],sp.history.dimensions())

# %%
plots.arrayPlot(np.random.rand(50,50))

# %%
dA=np.zeros([100,20*20])
i=0
for indexes in sp.history.activeColumns():
    dA[i][indexes]=1
    i=i+1

arrayPlot(np.reshape(np.mean(dA, axis=0),[20,20]))

# %%
c=1
p=np.zeros(625)
perm=np.zeros(625)
sp.getPotential(c,p)
sp.getPermanence(c,perm)
arrayPlot(p.reshape([25,25]))
arrayPlot(perm.reshape([25,25]))
print np.sum(p)
# Out:
# 41.0

# %%
ac=sp.history.activeColumns()[-1]

# %%
cs=np.zeros([len(ac),625])
i=0
for column in ac:
    sp.getConnectedSynapses(column,cs[i])
    i=i+1

# %%
plots.arrayPlot(np.sum(cs,axis=0).reshape([25,25]))

# %%
plots.sparseArrayPlot(sp.history.inputVector()[-1],sp.history.inputDimensions())

# %% [markdown]
# # Column Activation Counts

# %%
import itertools
cf=list(itertools.chain.from_iterable(sp.history.activeColumns()))

# %%
plt.hist(cf,bins=400)
fig = plt.gcf()
fig.set_size_inches([18,2])

# %% [markdown]
# # Density SDR

# %%
from nitpick.fileIO import History
h = History('/home/ruaridh/nitpick/nitpick/documentation/exampleData')

# %%
from nitpick import plots
(f,a)=plots.densityOrderedSDRPlot(h.activeColumns())

# %% [markdown]
# A better looking version of SDR plot is below. It replaces all the points with cirsles of the right size. But because of this it now goes horredously slowly.

# %%
import numpy
import matplotlib.pyplot as plt
import matplotlib
from nitpick.plots.tools import flatten

def timeOrderedSDRPlot(activeColumns):
    #Make sure inputs are numpy arrays
    activeColumns = numpy.asarray(activeColumns)
    
    
    ##Transform the input values into x and y coordinates
    
    #for each active bit, the x value is the time when it was active
    xValues = []
    for t in xrange(len(activeColumns)):
        xValues.append([t]*len(activeColumns[t]))
    xValues = numpy.fromiter(flatten(xValues),int) #not sure if int is the right thing to use here
    

    #Calculate y values 
    #for each active bit the y value is the time when that bit was first active
    def transformActiveColumnIndexes(activeColumns):

        pastIndexes = []
        yValues = []
        for activeColumn in flatten(activeColumns):
            if activeColumn not in pastIndexes:
                pastIndexes.append(activeColumn)
            yValue = pastIndexes.index(activeColumn)
            yValues.append(yValue)

        return yValues

    yValues = numpy.asarray(transformActiveColumnIndexes(activeColumns))
    
    ##Plot the x and y coordinates
    
    #set up plot
    (figure,axes) = plt.subplots()
    
    #plot the active bits
    #old line ->  axes.plot(xValues,yValues,'.')
    for coord in zip(xValues,yValues):
        point = plt.Circle(coord,radius=0.5,edgecolor='none',facecolor='#377eb8')
        axes.add_artist(point)
    axes.set_xlim(right=max(xValues)+1)
    axes.set_ylim(top=max(yValues)+1)
    
    
    #display the horizontal grid
    axes.minorticks_on()
    axes.grid(True,axis='both',which='both',linestyle='solid',color=(0.7,0.7,0.7))
    axes.set_axisbelow(True) #draw the lines beneath the points
    #Set the horizontal gridlines to have spacing of 1
    axes.yaxis.set_minor_locator(matplotlib.ticker.MultipleLocator(1))

    #Add a gap to the bottom and left edges so all points can be seen
    axes.set_xlim(left=-1)
    axes.set_ylim(bottom=-1)

    #set plot aspect ratio so the axes are even.
    axes.set_aspect(aspect='equal')
    #Make the plot bigger (the plot expands to box whilst retaining aspect ratio)
    figure.set_size_inches(20,20)
    
    return (figure, figure.axes)

# %%
timeOrderedSDRPlot(h.activeColumns()+h.activeColumns())
# Out:
# (<matplotlib.figure.Figure at 0x9d78fdcc>,
#  [<matplotlib.axes.AxesSubplot at 0x9d7b390c>])

# %%
def get_ax_size(fig,ax,units='inches'):
    """units are 'inches' or 'pixels' or 'points'"""
    bbox = ax.get_window_extent().transformed(fig.dpi_scale_trans.inverted())
    width, height = bbox.width, bbox.height
    if units=='pixels':
        width *= fig.dpi
        height *= fig.dpi
    elif units=='points':
        width *= 72
        height *= 72
    elif units=='inches':
        pass
    else:
        assert False
    return width, height # in inches

#size = area
#area = pi (0.5du * points/du)**2
#points/du = ax length (points)/ax length (du)
#ax length (points) = ax length(inches)*72

# %%
plt.plot([1,2,3,4])
f=plt.gcf()
a=plt.gca()
f.set_size_inches(6,6)

# %%
get_ax_size(f,a,units='inches')
# Out:
# (4.6500000000000004, 4.6500000000000004)

# %% [markdown]
# # Hinton Plot - copied from matplotlib examples

# %%
def hinton(matrix, max_weight=None, ax=None):
    """Draw Hinton diagram for visualizing a weight matrix."""
    ax = ax if ax is not None else plt.gca()

    if not max_weight:
        max_weight = 2**np.ceil(np.log(np.abs(matrix).max())/np.log(2))

    ax.patch.set_facecolor('gray')
    ax.set_aspect('equal', 'box')
    ax.xaxis.set_major_locator(plt.NullLocator())
    ax.yaxis.set_major_locator(plt.NullLocator())

    for (x,y),w in np.ndenumerate(matrix):
        color = 'white' if w > 0 else 'black'
        size = np.sqrt(np.abs(w))
        rect = plt.Rectangle([x - size / 2, y - size / 2], size, size,
                             facecolor=color, edgecolor=color)
        ax.add_patch(rect)

    ax.autoscale_view()
    ax.invert_yaxis()

# %%
hinton(np.random.rand(20, 20) - 0.5)
