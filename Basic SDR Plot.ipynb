# %% [markdown]
# # Basic Plot Of SDR's

# %% [markdown]
# This is an example of the sort of visualisations I'm trying to put together.
#
# The plot shows the SDR's calculated by a particular spatial pooler as it runs through a data set.
#
# Each horizontal line is a plot of a 1D SDR computed at one timestep, with succesive timesteps going down the page. Black squares correspond to active columns and white rectangles to inactive columns. Note that the inactive columns have been squashed hosizontally to allow everything to fit neatly.
#
# This is just a mock up to get the idea across, this exact plot could do with some refining.

# %%
from IPython.display import Image
Image(filename='C:\\Users\\Ruaridh\\Documents\\SDRPlot.png',width='100%')

# %% [markdown]
# The same thing as above but rotated left by 90. Now time increases to the right and you can see the whole thing in one glance.
#
# Each SDR is 200 columns wide with 2% active columns. There are 101 timesteps.

# %%
Image(filename='C:\\Users\\Ruaridh\\Documents\\SDRPlot(rotated).png',width='100%')
