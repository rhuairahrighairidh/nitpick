# %% [markdown]
# ### Initialisation

# %%
import numpy as np
# %matplotlib inline
# %autosave 0
# Out:
# Autosave disabled

# %% [markdown]
# # Density Ordered SDR Plot

# %% [markdown]
# This plot shows the active cells/columns in a region at each timestep.
#
# Time increases to the right. Each horizontal line represents one cell. The dots show when it was active. The dots that lie vertically above each other show the active cells at that time step.
# All topology has been removed in this plot.
# The cells/columns are ordered so that the one which as most active is at the bottom. The numbers on the left show how many times the columns were active.

# %% [markdown]
# ### Get some input

# %% [markdown]
# The data here was produced by a small spatial pooler fed with random data.

# %%
from nitpick.fileIO import History
h = History('/home/ruaridh/nitpick/nitpick/documentation/exampleData')

# %% [markdown]
# ### Draw The Plot

# %%
from nitpick import plots
plots.densityOrderedSDRPlot(h.activeColumns())
# Out:
# (<matplotlib.figure.Figure at 0xb1272e4c>,
#  [<matplotlib.axes.AxesSubplot at 0xb12742ac>])

# %% [markdown]
# ### Implementation Details

# %% [markdown]
#  - Numbers on the left are usually overlapping
#  - might be nice to color the bands
#  - the name is a bit long
#  - on the whole this plot isn't so useful - could be dropped or incorporated into timeOrderedSDRPlot through a key word argument
