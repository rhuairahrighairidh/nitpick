# %% [markdown]
# # Initialization

# %%
import matplotlib.pyplot as plt
import numpy as np
# %matplotlib inline

# %% [markdown]
# # Setup.py

# %%
from setuptools import setup, find_packages

# %%
import os
os.getcwd()
# Out:
# '/home/ruaridh/nitpick/development'

# %%
# %ls
# Out:
# DataHandlingExperiments.ipynb  OtherThings.ipynb          ProjectNameIdeas.txt~
# HotGymDemo.ipynb               PlottingExperiments.ipynb  swarmy/
# HotGym.ipynb                   ProjectNameIdeas.txt       test.h5

# %%
# %cd ..
# Out:
# /home/ruaridh/nitpick

# %%
find_packages()
# Out:
# ['nitpick', 'nitpick.cerebro2', 'nitpick.plots']

# %% [markdown]
# Reasons for using pip install:
#     - keeps to standard methods
#     - deals with the dependencies
#     - allows easy uninstalling
#     - 'properly installs things'
# find out what pip install from github does
# with the -e option, pip clones the repo into src/projectRepo/ then installs it (in editable mode)
# without the -e option pip (builds in temp) then installs normally
#
# it could just instal the bits specified in setup.py (in which case include the documentation)
# or it could clone the whole lot (in which case do you need to tell it to include the documentation)
# (how should one access the documentation anyway?)
#
# I can also get pip to install from a github download link (one that sends the zipped repo) (no git required)
#
# if I was to release this projct on the PYPI then I'd want to specify that the documentation is included - otherwise it will not be packaged up into the .tar.gz
#
#
# Plan: have two options
# 1. Simple option - pip install from github download link into virtual env (also install ipython into virtualenv)
# 2. Developer option - clone repo, pip install with -e option (into virtualenv)(also install ipython into virtualenv)
#
# it will be setup to include the documentation files in the install (so every person will get copy of docs)
#
# wether docs in included in 'the package' or above it doesn't matter - just a matter of project file structure

# %% [markdown]
# # Draw a D3 version of the active column plot

# %% [markdown]
# This package will hopefully allow interactivity.
# Formatting isn't precisely replicated

# %%
import mpld3

# %%
mpld3.display(figure)
# Out:
# <style>
#
# </style>
#
# <div id="fig_el1424329416287169968130467"></div>
# <script>
# function mpld3_load_lib(url, callback){
#   var s = document.createElement('script');
#   s.src = url;
#   s.async = true;
#   s.onreadystatechange = s.onload = callback;
#   s.onerror = function(){console.warn("failed to load library " + url);};
#   document.getElementsByTagName("head")[0].appendChild(s);
# }
#
# if(typeof(mpld3) !== "undefined" && mpld3._mpld3IsLoaded){
#    // already loaded: just create the figure
#    !function(mpld3){
#
# ...

# %% [markdown]
# # Data Loading Thoughts

# %% [markdown]
# ``somewhereElse.actualActiveColumnPlot(dataArray1,dataArray2,optionalMatplotlibArgs)``
# ``ruplot.activeColumnPlot(spInstance, optionalTimeRange, optionalMatplotlibArgs)``
# ``ruplot.activeColumnPlot(modelID, ...)``

# %%
def somePlot():
    if not actualData:
        datahistory = History(modelID)
        datahistory = spInstance.history
        
        dataArray1 = datahistory.something()
    
    #carry on with plot function

# %% [markdown]
# # Assortment of Matplotlib plots

# %%
plt.hlines([1,2,4,5],[0,0,3,0],[1,2,5,1],colors=((1,0,1)))

# %%
plt.matshow(np.random.randn(10,20))

# %%
plt.pcolormesh(np.random.randn(10,20))
